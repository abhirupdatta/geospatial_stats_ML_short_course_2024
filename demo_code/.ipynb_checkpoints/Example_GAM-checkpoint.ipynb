# %%
import torch
import geospaNN
import numpy as np
import time
import pandas as pd
import seaborn as sns
import scipy
import lhsmdu

import matplotlib
import matplotlib.pyplot as plt

path = '/Users/zhanwentao/Documents/Abhi/Conference/IBC2024/data/'

# %%
def RMSE(x,y):
    x = x.reshape(-1)
    y = y.reshape(-1)
    n = x.shape[0]
    return(np.sqrt(np.sum(np.square(x-y))/n))


sigma = 1
phi = 3
tau = 0.01
theta = torch.tensor([sigma, phi / np.sqrt(2), tau])

p = 5;
funXY = f5

n = 1000
nn = 20
batch_size = 50

N = 1000
n_small = int(N / 100)
np.random.seed(2021)
X_MISE = np.array(lhsmdu.sample(p, n_small).reshape((n_small, p)))
for i in range(99):
    temp = np.array(lhsmdu.sample(p, n_small).reshape((n_small, p)))
    X_MISE = np.concatenate((X_MISE, temp))

X_MISE_torch = torch.from_numpy(X_MISE).float()

# %%
def f5(X): return (10 * np.sin(np.pi * X[:, 0] * X[:, 1]) + 20 * (X[:, 2] - 0.5) ** 2 + 10 * X[:, 3] + 5 * X[:, 4]) / 6

funXY = f5

torch.manual_seed(2024)
X, Y, coord, cov, corerr = geospaNN.Simulation(n, p, nn, funXY, theta, range=[0, 10])

X, Y, coord, _ = geospaNN.spatial_order(X, Y, coord, method='max-min')
data = geospaNN.make_graph(X, Y, coord, nn)

torch.manual_seed(2024)
np.random.seed(0)
data_train, data_val, data_test = geospaNN.split_data(X, Y, coord, neighbor_size=nn,
                                                      test_proportion=0.2)

# %%
def f5(X): return (10 * np.sin(np.pi * X[:, 0] * X[:, 1]) + 20 * (X[:, 2] - 0.5) ** 2 + 10 * X[:, 3] + 5 * X[:, 4]) / 6

funXY = f5

torch.manual_seed(2024)
X, Y, coord, cov, corerr = geospaNN.Simulation(n, p, nn, funXY, theta, range=[0, 10])

X, Y, coord, _ = geospaNN.spatial_order(X, Y, coord, method='max-min')
data = geospaNN.make_graph(X, Y, coord, nn)

torch.manual_seed(2024)
np.random.seed(0)
data_train, data_val, data_test = geospaNN.split_data(X, Y, coord, neighbor_size=nn,
                                                      test_proportion=0.2)

# %%
import utils_pygam

# %%
mlp_nn = torch.nn.Sequential(
    torch.nn.Linear(p, 50),
    torch.nn.Sigmoid(),
    torch.nn.Linear(50, 1)
)
nn_model = geospaNN.nn_train(mlp_nn, lr=0.01, min_delta=0.001)
training_log = nn_model.train(data_train, data_val, data_test)
theta0 = geospaNN.theta_update(torch.tensor([1, 1.5, 0.01]), mlp_nn(data_train.x).squeeze() - data_train.y,
                               data_train.pos, neighbor_size=20)
# Out:
# Epoch 00048: reducing learning rate of group 0 to 5.0000e-03.
# INFO: Early stopping
# End at epoch49
# Theta updated from
# [1.   1.5  0.01]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------

# %%
MSE_NN = []
Est_NN = mlp_nn(X_MISE_torch).detach().numpy()
MSE_NN.append(RMSE(Est_NN, funXY(X_MISE)))
MSE_NN
# Out:
# [0.419156359761267]

# %%
mlp_nngls = torch.nn.Sequential(
    torch.nn.Linear(p, 50),
    torch.nn.Sigmoid(),
    torch.nn.Linear(50, 20),
    torch.nn.Sigmoid(),
    torch.nn.Linear(20, 1)
)
model_nngls = geospaNN.nngls(p=p, neighbor_size=nn, coord_dimensions=2, mlp=mlp_nngls, theta=torch.tensor(theta0))
nngls_model = geospaNN.nngls_train(model_nngls, lr=0.1, min_delta=0.001)
training_log = nngls_model.train(data_train, data_val, data_test,
                                 Update_init=20, Update_step=10)
# Out:
# Epoch 00010: reducing learning rate of group 0 to 5.0000e-02.
# Epoch 00020: reducing learning rate of group 0 to 2.5000e-02.
# Theta updated from
# [0.78306741 2.84271057 0.21013543]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.81104223 2.82698453 0.13563897]
# Theta updated from
# [0.81104223 2.82698453 0.13563897]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [8.91048009e-01 2.98813077e+00 1.00000000e-08]
# Epoch 00039: reducing learning rate of group 0 to 1.2500e-02.
# Theta updated from
# [8.91048009e-01 2.98813077e+00 1.00000000e-08]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.84266768 2.7652932  0.03128451]
# Theta updated from
# [0.84266768 2.7652932  0.03128451]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [8.60180605e-01 2.71460501e+00 1.00000000e-08]
# Epoch 00053: reducing learning rate of group 0 to 6.2500e-03.
# INFO: Early stopping
# End at epoch56

# %%
MSE_NNGLS = []
Est_NNGLS = mlp_nngls(X_MISE_torch).detach().numpy()
MSE_NNGLS.append(RMSE(Est_NNGLS, funXY(X_MISE)))
MSE_NNGLS
# Out:
# [0.2556072808726216]

# %%
torch.manual_seed(2024)
np.random.seed(2024)
X_train = data_train.x.detach().numpy()
Y_train = data_train.y.detach().numpy()
gam = utils_pygam.my_LinearGAM()
gam.fit(X_train, Y_train)
Xspline = gam._modelmat(X_train)
gam.my_fit(X_train, Xspline, Y_train)
# Out:
# my_LinearGAM(callbacks=[Deviance(), Diffs()], fit_intercept=True,
#    max_iter=100, scale=None,
#    terms=s(0) + s(1) + s(2) + s(3) + s(4) + intercept, tol=0.0001,
#    verbose=False)

# %%
MSE_GAM = []
Est_GAM = gam.predict(X_MISE)
MSE_GAM.append(RMSE(Est_GAM, funXY(X_MISE)))
MSE_GAM
# Out:
# [0.3643964685237286]

# %%
torch.manual_seed(2024)
np.random.seed(2024)
X_train = data_train.x.detach().numpy()
Y_train = data_train.y.detach().numpy()
gam = utils_pygam.my_LinearGAM()
gam.fit(X_train, Y_train)
Xspline = gam._modelmat(X_train)
I_B_GAM, F_GAM = geospaNN.make_bf(data_train.pos, theta0, nn)
I_B_GAM = I_B_GAM.to_dense()
F_GAM = F_GAM.detach().numpy()
FI_B_GAM = (I_B_GAM.T * np.sqrt(np.reciprocal(F_GAM))).T
gam.my_fit(X_train,
           scipy.sparse.csr_matrix(np.matmul(FI_B_GAM, Xspline.todense())),
           np.array(np.matmul(FI_B_GAM, Y_train)))
# Out:
# my_LinearGAM(callbacks=[Deviance(), Diffs()], fit_intercept=True,
#    max_iter=100, scale=None,
#    terms=s(0) + s(1) + s(2) + s(3) + s(4) + intercept, tol=0.0001,
#    verbose=False)

# %%
MSE_GAMGLS = []
Est_GAMGLS = gam.predict(X_MISE)
MSE_GAMGLS.append(RMSE(Est_GAMGLS, funXY(X_MISE)))
MSE_GAMGLS
# Out:
# [0.3063997476112886]

# %%
rho_vec = []
MSE_GAMGLS = []
MSE_NNGLS = []
for rho in list(np.array(range(21))/20):
    print(rho)
    def f5(X): return rho * (10 * np.sin(np.pi * X[:, 0] * X[:, 1]))/3 + \
                      (1-rho)*(20 * (X[:, 2] - 0.5) ** 2 + 10 * X[:, 3] + 5 * X[:,4]) / 3

    funXY = f5
    torch.manual_seed(2024)
    X, Y, coord, cov, corerr = geospaNN.Simulation(n, p, nn, funXY, theta, range=[0, 10])
    
    X, Y, coord, _ = geospaNN.spatial_order(X, Y, coord, method='max-min')
    data = geospaNN.make_graph(X, Y, coord, nn)
    torch.manual_seed(2024)
    np.random.seed(0)
    data_train, data_val, data_test = geospaNN.split_data(X, Y, coord, neighbor_size=nn,
                                                          test_proportion=0.2)
    mlp_nngls = torch.nn.Sequential(
        torch.nn.Linear(p, 50),
        torch.nn.ReLU(),
        torch.nn.Linear(50, 1)
    )
    model_nngls = geospaNN.nngls(p=p, neighbor_size=nn, coord_dimensions=2, mlp=mlp_nngls, theta=torch.tensor(theta0))
    nngls_model = geospaNN.nngls_train(model_nngls, lr=0.1, min_delta=0.001)
    training_log = nngls_model.train(data_train, data_val, data_test,
                                     Update_init=10, Update_step=5)
    Est_NNGLS = mlp_nngls(X_MISE_torch).detach().numpy()
    MSE_NNGLS.append(RMSE(Est_NNGLS, funXY(X_MISE)))
    
    torch.manual_seed(2024)
    np.random.seed(2024)
    X_train = data_train.x.detach().numpy()
    Y_train = data_train.y.detach().numpy()
    gam = utils_pygam.my_LinearGAM()
    gam.fit(X_train, Y_train)
    Xspline = gam._modelmat(X_train)
    I_B_GAM, F_GAM = geospaNN.make_bf(data_train.pos, theta0, nn)
    I_B_GAM = I_B_GAM.to_dense()
    F_GAM = F_GAM.detach().numpy()
    FI_B_GAM = (I_B_GAM.T * np.sqrt(np.reciprocal(F_GAM))).T
    gam.my_fit(X_train,
               scipy.sparse.csr_matrix(np.matmul(FI_B_GAM, Xspline.todense())),
               np.array(np.matmul(FI_B_GAM, Y_train)))
    
    Est_GAMGLS = gam.predict(X_MISE)
    MSE_GAMGLS.append(RMSE(Est_GAMGLS, funXY(X_MISE)))
    rho_vec.append(rho)
# Out:
# 0.0
# Theta updated from
# [0.78306741 2.84271057 0.21013543]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.87993798 2.51021882 0.03747565]
# Epoch 00014: reducing learning rate of group 0 to 5.0000e-02.
# Theta updated from
# [0.87993798 2.51021882 0.03747565]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.83958415 2.54577072 0.07061071]
# Theta updated from
# [0.83958415 2.54577072 0.07061071]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.87263816 2.41099719 0.01917153]
# Epoch 00024: reducing learning rate of group 0 to 2.5000e-02.
# Theta updated from
# [0.87263816 2.41099719 0.01917153]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.85843218 2.38392325 0.00761998]
# INFO: Early stopping
# End at epoch27
# 0.05
# Theta updated from
# [0.78306741 2.84271057 0.21013543]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.89249157 2.76143494 0.00959935]
# Epoch 00012: reducing learning rate of group 0 to 5.0000e-02.
# Theta updated from
# [0.89249157 2.76143494 0.00959935]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.84415776 2.58015788 0.03440695]
# Theta updated from
# [0.84415776 2.58015788 0.03440695]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.824886   2.51476032 0.03855429]
# Epoch 00025: reducing learning rate of group 0 to 2.5000e-02.
# Theta updated from
# [0.824886   2.51476032 0.03855429]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.83419364 2.60704953 0.04098937]
# INFO: Early stopping
# End at epoch28
# 0.1
# Theta updated from
# [0.78306741 2.84271057 0.21013543]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [9.26456662e-01 2.62330559e+00 1.00000000e-08]
# Theta updated from
# [9.26456662e-01 2.62330559e+00 1.00000000e-08]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [9.20962392e-01 2.60721668e+00 1.00000000e-08]
# Epoch 00018: reducing learning rate of group 0 to 5.0000e-02.
# Theta updated from
# [9.20962392e-01 2.60721668e+00 1.00000000e-08]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [9.18906233e-01 2.64023882e+00 1.00000000e-08]
# INFO: Early stopping
# End at epoch21
# 0.15
# Theta updated from
# [0.78306741 2.84271057 0.21013543]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.93373878 2.38388639 0.01078199]
# Theta updated from
# [0.93373878 2.38388639 0.01078199]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.99160639 2.54909818 0.00350515]
# Epoch 00017: reducing learning rate of group 0 to 5.0000e-02.
# Theta updated from
# [0.99160639 2.54909818 0.00350515]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [9.27862832e-01 2.31846152e+00 1.00000000e-08]
# Theta updated from
# [9.27862832e-01 2.31846152e+00 1.00000000e-08]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [9.27672115e-01 2.31953061e+00 1.00000000e-08]
# Theta updated from
# [9.27672115e-01 2.31953061e+00 1.00000000e-08]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [9.37434584e-01 2.32929990e+00 1.00000000e-08]
# Theta updated from
# [9.37434584e-01 2.32929990e+00 1.00000000e-08]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.92318911 2.27756207 0.00596139]
# Epoch 00039: reducing learning rate of group 0 to 2.5000e-02.
# Theta updated from
# [0.92318911 2.27756207 0.00596139]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [9.22908958e-01 2.28979041e+00 1.00000000e-08]
# INFO: Early stopping
# End at epoch42
# 0.2
# Theta updated from
# [0.78306741 2.84271057 0.21013543]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.90352583 2.85154923 0.0805033 ]
# Theta updated from
# [0.90352583 2.85154923 0.0805033 ]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.90296575 2.81066832 0.00753178]
# Theta updated from
# [0.90296575 2.81066832 0.00753178]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.89044071 2.76907544 0.01363891]
# Epoch 00023: reducing learning rate of group 0 to 5.0000e-02.
# Theta updated from
# [0.89044071 2.76907544 0.01363891]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [8.84718014e-01 2.80139574e+00 2.60098051e-05]
# INFO: Early stopping
# End at epoch26
# 0.25
# Theta updated from
# [0.78306741 2.84271057 0.21013543]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.95965289 2.65593288 0.0289381 ]
# Theta updated from
# [0.95965289 2.65593288 0.0289381 ]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.96276906 2.63043937 0.0136125 ]
# Theta updated from
# [0.96276906 2.63043937 0.0136125 ]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [9.50852223e-01 2.52875560e+00 1.00000000e-08]
# Epoch 00022: reducing learning rate of group 0 to 5.0000e-02.
# Theta updated from
# [9.50852223e-01 2.52875560e+00 1.00000000e-08]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [9.33517407e-01 2.43034878e+00 2.96463262e-05]
# Epoch 00030: reducing learning rate of group 0 to 2.5000e-02.
# Theta updated from
# [9.33517407e-01 2.43034878e+00 2.96463262e-05]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [9.27691925e-01 2.48569146e+00 1.62890186e-07]
# INFO: Early stopping
# End at epoch33
# 0.3
# Theta updated from
# [0.78306741 2.84271057 0.21013543]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.80386917 2.66180543 0.09847807]
# Theta updated from
# [0.80386917 2.66180543 0.09847807]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.78875663 2.50009763 0.11041762]
# Epoch 00018: reducing learning rate of group 0 to 5.0000e-02.
# Theta updated from
# [0.78875663 2.50009763 0.11041762]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.79710356 2.49400331 0.09787724]
# Epoch 00025: reducing learning rate of group 0 to 2.5000e-02.
# Theta updated from
# [0.79710356 2.49400331 0.09787724]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.79400419 2.5122071  0.1226526 ]
# INFO: Early stopping
# End at epoch28
# 0.35
# Theta updated from
# [0.78306741 2.84271057 0.21013543]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.81287156 2.56700739 0.13145215]
# Epoch 00012: reducing learning rate of group 0 to 5.0000e-02.
# Theta updated from
# [0.81287156 2.56700739 0.13145215]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.79955635 2.4506642  0.09054744]
# Theta updated from
# [0.79955635 2.4506642  0.09054744]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.79775057 2.42571859 0.0838942 ]
# Epoch 00021: reducing learning rate of group 0 to 2.5000e-02.
# INFO: Early stopping
# End at epoch24
# 0.4
# Theta updated from
# [0.78306741 2.84271057 0.21013543]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.87997261 2.73882166 0.07306425]
# Epoch 00014: reducing learning rate of group 0 to 5.0000e-02.
# Theta updated from
# [0.87997261 2.73882166 0.07306425]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.8646808  2.70566366 0.04328401]
# Theta updated from
# [0.8646808  2.70566366 0.04328401]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.87904791 2.6901547  0.03471505]
# Epoch 00023: reducing learning rate of group 0 to 2.5000e-02.
# Theta updated from
# [0.87904791 2.6901547  0.03471505]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [8.91781562e-01 2.74557322e+00 1.48635255e-03]
# INFO: Early stopping
# End at epoch26
# 0.45
# Theta updated from
# [0.78306741 2.84271057 0.21013543]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.8788904  2.7041408  0.12528271]
# Epoch 00015: reducing learning rate of group 0 to 5.0000e-02.
# Theta updated from
# [0.8788904  2.7041408  0.12528271]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.89276769 2.75164314 0.08060172]
# INFO: Early stopping
# End at epoch18
# 0.5
# Theta updated from
# [0.78306741 2.84271057 0.21013543]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.89465818 3.03751575 0.10222754]
# Theta updated from
# [0.89465818 3.03751575 0.10222754]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.92688276 3.26338352 0.04653467]
# Epoch 00018: reducing learning rate of group 0 to 5.0000e-02.
# Theta updated from
# [0.92688276 3.26338352 0.04653467]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.83439728 2.70964875 0.05931148]
# Theta updated from
# [0.83439728 2.70964875 0.05931148]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.80038423 2.63920952 0.04760323]
# Theta updated from
# [0.80038423 2.63920952 0.04760323]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.80549292 2.71828492 0.0720275 ]
# Epoch 00031: reducing learning rate of group 0 to 2.5000e-02.
# INFO: Early stopping
# End at epoch32
# 0.55
# Epoch 00009: reducing learning rate of group 0 to 5.0000e-02.
# Theta updated from
# [0.78306741 2.84271057 0.21013543]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.9379886  2.69640404 0.10214235]
# Theta updated from
# [0.9379886  2.69640404 0.10214235]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.9390817  2.70024826 0.06332523]
# Theta updated from
# [0.9390817  2.70024826 0.06332523]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [9.39534478e-01 2.58887368e+00 2.07367989e-04]
# Theta updated from
# [9.39534478e-01 2.58887368e+00 2.07367989e-04]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.94188362 2.62112146 0.02323906]
# Theta updated from
# [0.94188362 2.62112146 0.02323906]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [8.99237604e-01 2.51013441e+00 1.02994302e-06]
# Epoch 00032: reducing learning rate of group 0 to 2.5000e-02.
# Theta updated from
# [8.99237604e-01 2.51013441e+00 1.02994302e-06]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [8.75124139e-01 2.41736679e+00 1.00000000e-08]
# Theta updated from
# [8.75124139e-01 2.41736679e+00 1.00000000e-08]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [8.62634387e-01 2.40928012e+00 1.00000000e-08]
# Epoch 00045: reducing learning rate of group 0 to 1.2500e-02.
# Theta updated from
# [8.62634387e-01 2.40928012e+00 1.00000000e-08]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [8.69034942e-01 2.39817477e+00 9.00677796e-04]
# INFO: Early stopping
# End at epoch48
# 0.6
# Theta updated from
# [0.78306741 2.84271057 0.21013543]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.93775451 2.86638609 0.07223819]
# Theta updated from
# [0.93775451 2.86638609 0.07223819]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.93465507 2.73344801 0.08750331]
# Theta updated from
# [0.93465507 2.73344801 0.08750331]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.87202087 2.54631821 0.07263974]
# Theta updated from
# [0.87202087 2.54631821 0.07263974]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.90058251 2.63686182 0.01302808]
# Theta updated from
# [0.90058251 2.63686182 0.01302808]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.87241679 2.48449956 0.06921861]
# Epoch 00034: reducing learning rate of group 0 to 5.0000e-02.
# Theta updated from
# [0.87241679 2.48449956 0.06921861]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.89693323 2.58208074 0.02690033]
# INFO: Early stopping
# End at epoch37
# 0.65
# Theta updated from
# [0.78306741 2.84271057 0.21013543]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.84602812 2.771106   0.11916723]
# Theta updated from
# [0.84602812 2.771106   0.11916723]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.85030151 2.92438024 0.04994391]
# Epoch 00019: reducing learning rate of group 0 to 5.0000e-02.
# Theta updated from
# [0.85030151 2.92438024 0.04994391]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.79307542 2.66630441 0.05669795]
# INFO: Early stopping
# End at epoch22
# 0.7
# Theta updated from
# [0.78306741 2.84271057 0.21013543]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.86019473 2.59009523 0.10747211]
# Theta updated from
# [0.86019473 2.59009523 0.10747211]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# ...
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [9.32923968e-01 2.86588211e+00 4.41910929e-04]
# Theta updated from
# [9.32923968e-01 2.86588211e+00 4.41910929e-04]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.9141577  2.84656697 0.02155714]
# Theta updated from
# [0.9141577  2.84656697 0.02155714]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [9.00399466e-01 2.70491460e+00 1.00000000e-08]
# Theta updated from
# [9.00399466e-01 2.70491460e+00 1.00000000e-08]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [9.24026981e-01 2.70287364e+00 1.00000000e-08]
# Epoch 00038: reducing learning rate of group 0 to 5.0000e-02.
# Theta updated from
# [9.24026981e-01 2.70287364e+00 1.00000000e-08]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [9.06913241e-01 2.68080439e+00 1.00000000e-08]
# INFO: Early stopping
# End at epoch41
# 0.95
# Theta updated from
# [0.78306741 2.84271057 0.21013543]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.84935871 2.70998356 0.33124279]
# Theta updated from
# [0.84935871 2.70998356 0.33124279]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.81940369 2.6660838  0.19652334]
# Theta updated from
# [0.81940369 2.6660838  0.19652334]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.8121686  2.71990017 0.29738619]
# Epoch 00021: reducing learning rate of group 0 to 5.0000e-02.
# Theta updated from
# [0.8121686  2.71990017 0.29738619]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.83604261 2.61313588 0.16508349]
# Theta updated from
# [0.83604261 2.61313588 0.16508349]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.84255231 2.6623226  0.15701174]
# Epoch 00031: reducing learning rate of group 0 to 2.5000e-02.
# Theta updated from
# [0.84255231 2.6623226  0.15701174]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.82543561 2.63239263 0.16954765]
# Epoch 00040: reducing learning rate of group 0 to 1.2500e-02.
# Theta updated from
# [0.82543561 2.63239263 0.16954765]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.81740858 2.62697252 0.1674025 ]
# INFO: Early stopping
# End at epoch43
# 1.0
# Theta updated from
# [0.78306741 2.84271057 0.21013543]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.83613115 2.62738154 0.41994072]
# Theta updated from
# [0.83613115 2.62738154 0.41994072]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.83024797 2.67866405 0.32811208]
# Theta updated from
# [0.83024797 2.67866405 0.32811208]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.80962091 2.63675021 0.15289516]
# Theta updated from
# [0.80962091 2.63675021 0.15289516]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.83652565 2.83617121 0.06156321]
# Epoch 00030: reducing learning rate of group 0 to 5.0000e-02.
# Theta updated from
# [0.83652565 2.83617121 0.06156321]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.819564   2.66166187 0.17797137]
# Theta updated from
# [0.819564   2.66166187 0.17797137]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.83565191 2.80756411 0.07694576]
# Theta updated from
# [0.83565191 2.80756411 0.07694576]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.79843971 2.58927362 0.06156508]
# Theta updated from
# [0.79843971 2.58927362 0.06156508]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.80613848 2.61517917 0.04867627]
# Theta updated from
# [0.80613848 2.61517917 0.04867627]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.7875058  2.48290056 0.17827544]
# Epoch 00053: reducing learning rate of group 0 to 2.5000e-02.
# Theta updated from
# [0.7875058  2.48290056 0.17827544]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.79957988 2.62385266 0.04276872]
# INFO: Early stopping
# End at epoch56

# %%
df_MSE = pd.DataFrame(
    {'GAMGLS': np.array(MSE_GAMGLS), 'NNGLS': np.array(MSE_NNGLS), 'rho': np.array(rho_vec)})
df_MSE
# Out:
#       GAMGLS     NNGLS   rho
# 0   0.256314  0.170572  0.00
# 1   0.262675  0.243015  0.05
# 2   0.268375  0.242885  0.10
# 3   0.243490  0.275225  0.15
# 4   0.246049  0.265153  0.20
# 5   0.258383  0.245343  0.25
# 6   0.294365  0.221512  0.30
# 7   0.282499  0.228253  0.35
# 8   0.263470  0.292591  0.40
# 9   0.292330  0.424017  0.45
# 10  0.306792  0.219728  0.50
# 11  0.300050  0.214994  0.55
# 12  0.332101  0.234560  0.60
# 13  0.372532  0.363394  0.65
# 14  0.369784  0.244005  0.70
# 15  0.382135  0.275009  0.75
# 16  0.392831  0.258366  0.80
# 17  0.419862  0.283364  0.85
# 18  0.435673  0.168702  0.90
# 19  0.471164  0.405832  0.95
# 20  0.476859  0.256113  1.00

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Plot using Matplotlib
plt.figure(figsize=(8, 6))
plt.scatter(df_MSE['rho'], df_MSE['GAMGLS'], label='GAMGLS', marker='o')
plt.scatter(df_MSE['rho'], df_MSE['NNGLS'], label='NNGLS', marker='s')

# Add titles and labels
plt.title('MSE vs strength of interaction', fontsize=14)
plt.xlabel('Strength of interaction (rho)', fontsize=12)
plt.ylabel('Mean Squared Error (MSE)', fontsize=12)
plt.legend(fontsize=12)
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %%
degree = 3  # Degree of the polynomial
rho_smooth = np.linspace(df_MSE['rho'].min(), df_MSE['rho'].max(), 200)

# Fit polynomials for GAMGLS and NNGLS
gamgls_fit = np.polyfit(df_MSE['rho'], df_MSE['GAMGLS'], degree)
nngls_fit = np.polyfit(df_MSE['rho'], df_MSE['NNGLS'], degree)

# Evaluate the polynomial on a smooth grid
gamgls_smooth = np.polyval(gamgls_fit, rho_smooth)
nngls_smooth = np.polyval(nngls_fit, rho_smooth)

# Plot using Matplotlib
plt.clf()
plt.figure(figsize=(8, 6))

# Original points
plt.plot(df_MSE['rho'], df_MSE['GAMGLS'], label='GAMGLS (Data)', marker='o', linestyle='none')
plt.plot(df_MSE['rho'], df_MSE['NNGLS'], label='NNGLS (Data)', marker='s', linestyle='none')

# Smoothed curves
plt.plot(rho_smooth, gamgls_smooth, label='GAMGLS (Smoothed)', color='blue', linestyle='-', linewidth=1.5)
plt.plot(rho_smooth, nngls_smooth, label='NNGLS (Smoothed)', color='orange', linestyle='-', linewidth=1.5)
# Add titles and labels
plt.title('MSE vs strength of interaction', fontsize=14)
plt.xlabel('Strength of interaction (rho)', fontsize=12)
plt.ylabel('Mean Squared Error (MSE)', fontsize=12)
plt.legend(fontsize=12)
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()
