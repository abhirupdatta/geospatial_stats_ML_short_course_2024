# %%
import torch
import geospaNN
import numpy as np
import time
import pandas as pd
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt

path = '/Users/zhanwentao/Documents/Abhi/Conference/IBC2024/data/'
# Out:
# R[write to console]: Loading required package: BRISC
#
# R[write to console]: Loading required package: RANN
#
# R[write to console]: Loading required package: parallel
#
# R[write to console]: Loading required package: rdist
#
# R[write to console]: Loading required package: matrixStats
#
# R[write to console]: Loading required package: pbapply
#
# R[write to console]: The ordering of inputs x (covariates) and y (response) in BRISC_estimation has been changed BRISC 1.0.0 onwards.
#   Please check the new documentation with ?BRISC_estimation.
# R package: BRISC installed
# /Users/zhanwentao/opt/anaconda3/envs/NN/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
from scipy.interpolate import griddata, CloughTocher2DInterpolator
from typing import Callable, Optional, Tuple
import warnings
def spatial_plot_surface(variable: np.array,
                         coord: np.array,
                         title: Optional[str] = "Variable",
                         save_path: Optional[str] = "./",
                         file_name: Optional[str] = "spatial_surface.png",
                         grid_resolution: Optional[int] = 1000,
                         method: Optional[str] = "CloughTocher",
                         cmap: Optional[str] = 'viridis',
                         show: Optional[bool] = False
                         ) -> None:
    """
    Plots a smooth surface for spatial data.

    The function interpolates scattered data onto a regular grid and generates
    a smooth surface plot. The resulting plot is saved as a PNG file.

    Parameters:
        variable (array-like): Values to plot, corresponding to the coordinates.
        coord (array-like): Coordinates of shape (n, 2) where each row represents a point (x, y).
        title (str, optional): Title of the plot. Defaults to "Variable".
        save_path (str, optional): Directory to save the plot. Defaults to "./".
        file_name (str, optional): Name of the saved plot file. Defaults to "spatial_surface.png".
        grid_resolution (int, optional): Resolution of the interpolation grid.
            Higher values produce finer surfaces. Defaults to 100.
        cmap (str, optional): Colormap to use for the plot. Defaults to 'viridis'.

    Raises:
        ValueError: If the lengths of `variable` and `coord` do not match.

    Returns:
        None: The function saves the plot to a file and does not return any value.

    Example:
        >>> import numpy as np
        >>> coord = np.random.uniform(0, 10, (50, 2))
        >>> variable = np.sin(coord[:, 0]) + np.cos(coord[:, 1])
        >>> spatial_plot_surface(variable, coord, title="Example Plot", grid_resolution=200)
    """
    if len(variable) != len(coord):
        raise ValueError("Length of 'variable' and 'coord' must match.")

    # Create grid for interpolation
    xi = np.linspace(coord[:, 0].min(), coord[:, 0].max(), grid_resolution)
    yi = np.linspace(coord[:, 1].min(), coord[:, 1].max(), grid_resolution)
    X, Y = np.meshgrid(xi, yi)

    # Interpolate data onto the grid

    if method == "CloughTocher":
        interp = CloughTocher2DInterpolator(list(zip(coord[:, 0], coord[:, 1])), variable)
        Z = interp(X, Y)
    elif method in ['linear', 'nearest', 'cubic']:
        Z = griddata(coord, variable, (X, Y), method=method)
    else:
        warnings.warn("No interpolation method provided, use cubic spline as default!")
        Z = griddata(coord, variable, (X, Y), method="cubic")

    # Plot the interpolated surface
    plt.clf()
    fig = plt.figure(figsize=(8, 6))
    surface = plt.pcolormesh(X, Y, Z, cmap=cmap, shading='auto')
    plt.colorbar(surface, label='Variable')
    plt.title(title)
    plt.xlabel('Coord_X')
    plt.ylabel('Coord_Y')
    plt.savefig(f"{save_path}/{file_name}")
    if show:
        plt.show()

    return fig

# %%
def f1(X): return 10 * np.sin(np.pi * 2 * X)


sigma = 1
phi = 0.1
tau = 0.01
theta = torch.tensor([sigma, phi / np.sqrt(2), tau])

p = 1;
funXY = f1

n = 1000
nn = 20
batch_size = 50

torch.manual_seed(2025)
#X, Y, coord, cov, corerr = geospaNN.Simulation(n, p, nn, funXY, theta, range=[0, 1])
_, _, _, _, X = geospaNN.Simulation(n, p, nn, funXY, torch.tensor([1, 5, 0.01]), range=[0, 1])
X = X.reshape(-1,1)
X = (X - X.min())/(X.max() - X.min())
torch.manual_seed(2025)
_, _, coord, cov, corerr = geospaNN.Simulation(n, p, nn, funXY, theta, range=[0, 1])
Y = funXY(X).reshape(-1) + corerr

dict = {"Covariate": X, "Response": Y, "Spatial_effect":corerr}

for index, (name, variable) in enumerate(dict.items()):
    spatial_plot_surface(variable.detach().numpy().reshape(-1), coord.detach().numpy(),
                         grid_resolution = 50, method = "CloughTocher",
                         title = name, save_path = path, file_name = name + ".png")

X, Y, coord, _ = geospaNN.spatial_order(X, Y, coord, method='max-min')
data = geospaNN.make_graph(X, Y, coord, nn)

torch.manual_seed(2024)
np.random.seed(0)
data_train, data_val, data_test = geospaNN.split_data(X, Y, coord, neighbor_size=nn,
                                                      test_proportion=0.2)

# %%
torch.manual_seed(2025)
mlp_nn = torch.nn.Sequential(
    torch.nn.Linear(p, 5),
    torch.nn.ReLU(),
    torch.nn.Linear(5, 1)
)
trainer_nn = geospaNN.nn_train(mlp_nn, lr=0.01, min_delta=0.001)
training_log = trainer_nn.train(data_train, data_val, data_test)
theta0 = geospaNN.theta_update(mlp_nn(data_train.x).squeeze() - data_train.y, data_train.pos, neighbor_size=20)
# Out:
# Epoch 00075: reducing learning rate of group 0 to 5.0000e-03.
# INFO: Early stopping
# End at epoch78
# Theta updated from
# [1.   1.5  0.01]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------

# %%
torch.manual_seed(2025)
mlp_linear = torch.nn.Sequential(
    torch.nn.Linear(p, 1),
)
model_linear = geospaNN.nngls(p=p, neighbor_size=nn, coord_dimensions=2, mlp=mlp_linear, theta = torch.tensor(theta0))
trainer_linear = geospaNN.nngls_train(model_linear, lr=0.01, min_delta=0.001)
training_log = trainer_linear.train(data_train, data_val, data_test,
                                        Update_init=10, Update_step=5)
# Out:
# Theta updated from
# [ 3.06058168 27.10265034  0.32714284]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [3.60180135e+01 1.25381438e+01 1.64829340e-02]
# Theta updated from
# [3.60180135e+01 1.25381438e+01 1.64829340e-02]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [3.57004447e+01 1.25688118e+01 1.67506794e-02]
# Theta updated from
# [3.57004447e+01 1.25688118e+01 1.67506794e-02]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [3.54833057e+01 1.25898798e+01 1.69355933e-02]
# Theta updated from
# [3.54833057e+01 1.25898798e+01 1.69355933e-02]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [3.52409065e+01 1.26119301e+01 1.71498880e-02]
# Theta updated from
# [3.52409065e+01 1.26119301e+01 1.71498880e-02]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [3.49661368e+01 1.26406186e+01 1.73888281e-02]
# Theta updated from
# [3.49661368e+01 1.26406186e+01 1.73888281e-02]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [3.46757129e+01 1.26694291e+01 1.76528158e-02]
# Theta updated from
# [3.46757129e+01 1.26694291e+01 1.76528158e-02]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [3.43636924e+01 1.27016426e+01 1.79319878e-02]
# Theta updated from
# [3.43636924e+01 1.27016426e+01 1.79319878e-02]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [3.40318384e+01 1.27356941e+01 1.82490852e-02]
# Theta updated from
# [3.40318384e+01 1.27356941e+01 1.82490852e-02]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [3.36859129e+01 1.27726842e+01 1.85733290e-02]
# Theta updated from
# [3.36859129e+01 1.27726842e+01 1.85733290e-02]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [3.33228355e+01 1.28125204e+01 1.89240672e-02]
# Theta updated from
# [3.33228355e+01 1.28125204e+01 1.89240672e-02]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [3.29446444e+01 1.28545211e+01 1.93026050e-02]
# Theta updated from
# [3.29446444e+01 1.28545211e+01 1.93026050e-02]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [3.25582934e+01 1.28977478e+01 1.96994347e-02]
# Theta updated from
# [3.25582934e+01 1.28977478e+01 1.96994347e-02]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [3.21538286e+01 1.29451068e+01 2.01236708e-02]
# Theta updated from
# [3.21538286e+01 1.29451068e+01 2.01236708e-02]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [3.17427506e+01 1.29939841e+01 2.05678687e-02]
# Theta updated from
# [3.17427506e+01 1.29939841e+01 2.05678687e-02]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [3.13176656e+01 1.30470980e+01 2.10368382e-02]
# Theta updated from
# [3.13176656e+01 1.30470980e+01 2.10368382e-02]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [3.08892808e+01 1.30997655e+01 2.15307882e-02]
# Theta updated from
# [3.08892808e+01 1.30997655e+01 2.15307882e-02]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [3.04511996e+01 1.31562254e+01 2.20480498e-02]
# Theta updated from
# [3.04511996e+01 1.31562254e+01 2.20480498e-02]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [3.00079539e+01 1.32150160e+01 2.25890908e-02]

# %%
torch.manual_seed(2025)
mlp_l1_n5 = torch.nn.Sequential(
    torch.nn.Linear(p, 5),
    torch.nn.ReLU(),
    torch.nn.Linear(5, 1)
)
nngls_l1_n5 = geospaNN.nngls(p=p, neighbor_size=nn, coord_dimensions=2, mlp=mlp_l1_n5, theta=torch.tensor(theta0))
trainer_l1_n5 = geospaNN.nngls_train(nngls_l1_n5, lr=0.1, min_delta=0.001)
training_log = trainer_l1_n5.train(data_train, data_val, data_test,
                                   Update_init=20, Update_step=5)
# Out:
# Theta updated from
# [ 2.83598694 25.90605775  0.27308153]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [ 3.09494275 21.16675025  0.33952047]
# Epoch 00022: reducing learning rate of group 0 to 5.0000e-02.
# Theta updated from
# [ 3.09494275 21.16675025  0.33952047]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [ 3.13161665 20.61974533  0.33497688]
# INFO: Early stopping
# End at epoch25

# %%
torch.manual_seed(2025)
mlp_l1_n20 = torch.nn.Sequential(
    torch.nn.Linear(p, 20),
    torch.nn.ReLU(),
    torch.nn.Linear(20, 1)
)
nngls_l1_n20 = geospaNN.nngls(p=p, neighbor_size=nn, coord_dimensions=2, mlp=mlp_l1_n20, 
                              theta=torch.tensor(theta0))
trainer_l1_n20 = geospaNN.nngls_train(nngls_l1_n20, lr=0.1, min_delta=0.001)
training_log = trainer_l1_n20.train(data_train, data_val, data_test,
                                    Update_init=20, Update_step=5)
# Out:
# Theta updated from
# [ 3.06058168 27.10265034  0.32714284]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [ 1.69522757 15.69920218  0.32181646]
# Theta updated from
# [ 1.69522757 15.69920218  0.32181646]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [ 1.4087536  11.35316949  0.28788016]
# Theta updated from
# [ 1.4087536  11.35316949  0.28788016]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.88750829 9.6102334  0.36775785]
# Theta updated from
# [0.88750829 9.6102334  0.36775785]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [ 0.39467405 12.81579039  0.51353069]
# Theta updated from
# [ 0.39467405 12.81579039  0.51353069]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.17450399 6.65947657 0.91964844]
# Theta updated from
# [0.17450399 6.65947657 0.91964844]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.66574332 5.50849849 0.17179532]
# Epoch 00046: reducing learning rate of group 0 to 5.0000e-02.
# Theta updated from
# [0.66574332 5.50849849 0.17179532]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.28259052 3.87353666 0.34348086]
# Theta updated from
# [0.28259052 3.87353666 0.34348086]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.45479704 3.33508307 0.18398222]
# Epoch 00057: reducing learning rate of group 0 to 2.5000e-02.
# Theta updated from
# [0.45479704 3.33508307 0.18398222]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.50272086 2.68446883 0.14758009]
# Theta updated from
# [0.50272086 2.68446883 0.14758009]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.389052   2.77657894 0.19129921]
# Theta updated from
# [0.389052   2.77657894 0.19129921]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.39026859 2.76543054 0.18524053]
# Theta updated from
# [0.39026859 2.76543054 0.18524053]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.43041338 2.71570626 0.15965568]
# Theta updated from
# [0.43041338 2.71570626 0.15965568]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.31423857 3.43768368 0.21421751]
# Theta updated from
# [0.31423857 3.43768368 0.21421751]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.23002996 5.66964525 0.30535805]
# Theta updated from
# [0.23002996 5.66964525 0.30535805]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.39920722 2.84238701 0.14428216]
# Epoch 00094: reducing learning rate of group 0 to 1.2500e-02.
# INFO: Early stopping
# End at epoch93

# %%
torch.manual_seed(2025)
mlp_l1_n50 = torch.nn.Sequential(
    torch.nn.Linear(p, 50),
    torch.nn.ReLU(),
    torch.nn.Linear(50, 1)
)
nngls_l1_n50 = geospaNN.nngls(p=p, neighbor_size=nn, coord_dimensions=2, mlp=mlp_l1_n50, 
                              theta=torch.tensor(theta0))
trainer_l1_n50 = geospaNN.nngls_train(nngls_l1_n50, lr=0.1, min_delta=0.001)
training_log = trainer_l1_n50.train(data_train, data_val, data_test,
                                    Update_init=10, Update_step=5)
# Out:
# Theta updated from
# [ 3.06058168 27.10265034  0.32714284]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [ 2.8486387  24.14083513  0.33591948]
# Theta updated from
# [ 2.8486387  24.14083513  0.33591948]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [ 2.08106584 21.30875394  0.37627957]
# Theta updated from
# [ 2.08106584 21.30875394  0.37627957]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [ 1.19001268 20.14808136  0.46959535]
# Theta updated from
# [ 1.19001268 20.14808136  0.46959535]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [ 0.90744441 21.32546419  0.43561075]
# Theta updated from
# [ 0.90744441 21.32546419  0.43561075]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.69228042 8.3868813  0.4133221 ]
# Theta updated from
# [0.69228042 8.3868813  0.4133221 ]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [ 0.46350739 13.08545717  0.37146002]
# Theta updated from
# [ 0.46350739 13.08545717  0.37146002]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.63657942 4.6512791  0.18268548]
# Epoch 00045: reducing learning rate of group 0 to 5.0000e-02.
# Theta updated from
# [0.63657942 4.6512791  0.18268548]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.61408801 3.27322783 0.09922573]
# Theta updated from
# [0.61408801 3.27322783 0.09922573]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.49359493 3.73778006 0.0717673 ]
# Epoch 00054: reducing learning rate of group 0 to 2.5000e-02.
# Theta updated from
# [0.49359493 3.73778006 0.0717673 ]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.63993257 2.1169462  0.038482  ]
# Theta updated from
# [0.63993257 2.1169462  0.038482  ]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.40460285 2.25599854 0.04499315]
# Epoch 00062: reducing learning rate of group 0 to 1.2500e-02.
# Theta updated from
# [0.40460285 2.25599854 0.04499315]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.53630208 1.81407641 0.02512329]
# Theta updated from
# [0.53630208 1.81407641 0.02512329]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.354906   2.24040444 0.03387639]
# Theta updated from
# [0.354906   2.24040444 0.03387639]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.33747316 2.42089634 0.0317792 ]
# Epoch 00078: reducing learning rate of group 0 to 6.2500e-03.
# Theta updated from
# [0.33747316 2.42089634 0.0317792 ]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.25254299 3.7198718  0.03952245]
# INFO: Early stopping
# End at epoch81

# %%
torch.manual_seed(2025)
mlp_l2_n5_2 = torch.nn.Sequential(
    torch.nn.Linear(p, 5),
    torch.nn.ReLU(),
    torch.nn.Linear(5, 2),
    torch.nn.ReLU(),
    torch.nn.Linear(2, 1)
)
nngls_l2_n5_2 = geospaNN.nngls(p=p, neighbor_size=nn, coord_dimensions=2, mlp=mlp_l2_n5_2, theta=torch.tensor(theta0))
trainer_l2_n5_2 = geospaNN.nngls_train(nngls_l2_n5_2, lr=0.1, min_delta=0.001)
training_log = trainer_l2_n5_2.train(data_train, data_val, data_test,
                                     Update_init=10, Update_step=5)
# Out:
# Theta updated from
# [ 3.06058168 27.10265034  0.32714284]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [ 0.75197664 24.82007381  0.9498935 ]
# Theta updated from
# [ 0.75197664 24.82007381  0.9498935 ]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [ 0.63021583 13.12592369  0.89053633]
# Theta updated from
# [ 0.63021583 13.12592369  0.89053633]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [ 0.6218581  10.27952658  0.76544475]
# Theta updated from
# [ 0.6218581  10.27952658  0.76544475]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [ 0.5863034  10.60171622  0.72748581]
# Theta updated from
# [ 0.5863034  10.60171622  0.72748581]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.6495129  9.26937773 0.60068681]
# Epoch 00031: reducing learning rate of group 0 to 5.0000e-02.
# INFO: Early stopping
# End at epoch34

# %%
torch.manual_seed(2025)
mlp_l2_n50_20 = torch.nn.Sequential(
    torch.nn.Linear(p, 50),
    torch.nn.ReLU(),
    torch.nn.Linear(50, 20),
    torch.nn.ReLU(),
    torch.nn.Linear(20, 1)
)
nngls_l2_n50_20 = geospaNN.nngls(p=p, neighbor_size=nn, coord_dimensions=2, mlp=mlp_l2_n50_20, theta=torch.tensor(theta0))
trainer_l2_n50_20 = geospaNN.nngls_train(nngls_l2_n50_20, lr=0.1, min_delta=0.001)
training_log = trainer_l2_n50_20.train(data_train, data_val, data_test,
                                       Update_init=10, Update_step=5)
# Out:
# Theta updated from
# [ 3.06058168 27.10265034  0.32714284]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.58204094 6.56927734 0.28725069]
# Epoch 00012: reducing learning rate of group 0 to 5.0000e-02.
# Theta updated from
# [0.58204094 6.56927734 0.28725069]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.53614477 3.10259579 0.08139892]
# Theta updated from
# [0.53614477 3.10259579 0.08139892]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.62477107 4.22892253 0.04046841]
# Theta updated from
# [0.62477107 4.22892253 0.04046841]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.30588683 3.10266803 0.04074416]
# Epoch 00029: reducing learning rate of group 0 to 2.5000e-02.
# Theta updated from
# [0.30588683 3.10266803 0.04074416]
# ----------------------------------------
# 	Ordering Coordinates
# ----------------------------------------
# 	Model description
# ----------------------------------------
# BRISC model fit with 600 observations.
#
# Number of covariates 1 (including intercept if specified).
#
# Using the exponential spatial correlation model.
#
# Using 15 nearest neighbors.
#
#
#
# Source not compiled with OpenMP support.
# ----------------------------------------
# 	Building neighbor index
# ----------------------------------------
# 	Performing optimization
# ----------------------------------------
# 	Processing optimizers
# ----------------------------------------
# to
# [0.47775194 4.35630896 0.08113975]
# INFO: Early stopping
# End at epoch32

# %%
plt.clf()
plt.scatter(X.detach().numpy(), Y.detach().numpy(), s=1, label='data')
plt.scatter(X.detach().numpy(), funXY(X.detach().numpy()), s=1, label='f(x)')
plt.scatter(X.detach().numpy(), mlp_l1_n5(X).detach().numpy(), s=1, label='NNGLS 1 layer 5 nodes')
#plt.scatter(X.detach().numpy(), mlp_l1_n20(X).detach().numpy(), s=1, label='NNGLS 1 layer 20 nodes')
#plt.scatter(X.detach().numpy(), mlp_l1_n50(X).detach().numpy(), s=1, label='NNGLS 1 layer 50 nodes')
lgnd = plt.legend()
for handle in lgnd.legend_handles:
    handle.set_sizes([10.0])
plt.savefig(path + 'l1n5.png')

# %%
plt.clf()
plt.scatter(X.detach().numpy(), Y.detach().numpy(), s=1, label='data')
plt.scatter(X.detach().numpy(), funXY(X.detach().numpy()), s=1, label='f(x)')
#plt.scatter(X.detach().numpy(), mlp_l1_n5(X).detach().numpy(), s=1, label='NNGLS 1 layer 5 nodes')
plt.scatter(X.detach().numpy(), mlp_l1_n20(X).detach().numpy(), s=1, label='NNGLS 1 layer 20 nodes')
#plt.scatter(X.detach().numpy(), mlp_l1_n50(X).detach().numpy(), s=1, label='NNGLS 1 layer 50 nodes')
lgnd = plt.legend()
for handle in lgnd.legend_handles:
    handle.set_sizes([10.0])
plt.savefig(path + 'l1n20.png')

# %%
plt.clf()
plt.scatter(X.detach().numpy(), Y.detach().numpy(), s=1, label='data')
plt.scatter(X.detach().numpy(), funXY(X.detach().numpy()), s=1, label='f(x)')
#plt.scatter(X.detach().numpy(), mlp_l1_n5(X).detach().numpy(), s=1, label='NNGLS 1 layer 5 nodes')
#plt.scatter(X.detach().numpy(), mlp_l1_n20(X).detach().numpy(), s=1, label='NNGLS 1 layer 20 nodes')
plt.scatter(X.detach().numpy(), mlp_l1_n50(X).detach().numpy(), s=1, label='NNGLS 1 layer 50 nodes')
lgnd = plt.legend()
for handle in lgnd.legend_handles:
    handle.set_sizes([10.0])
plt.savefig(path + 'l1n50.png')

# %%
plt.clf()
plt.scatter(X.detach().numpy(), Y.detach().numpy(), s=1, label='data')
plt.scatter(X.detach().numpy(), funXY(X.detach().numpy()), s=1, label='f(x)')
plt.scatter(X.detach().numpy(), mlp_l2_n5_2(X).detach().numpy(), s=1, label='NNGLS 2 layers 5 2 nodes')
#plt.scatter(X.detach().numpy(), mlp_l2_n50_20(X).detach().numpy(), s=1, label='NNGLS 2 layers 50 20 nodes')
lgnd = plt.legend()
for handle in lgnd.legend_handles:
    handle.set_sizes([10.0])
plt.savefig(path + 'l2n5_2.png')

# %%
plt.clf()
plt.scatter(X.detach().numpy(), Y.detach().numpy(), s=1, label='data')
plt.scatter(X.detach().numpy(), funXY(X.detach().numpy()), s=1, label='f(x)')
#plt.scatter(X.detach().numpy(), mlp_l2_n5_2(X).detach().numpy(), s=1, label='NNGLS 2 layers 5 2 nodes')
plt.scatter(X.detach().numpy(), mlp_l2_n50_20(X).detach().numpy(), s=1, label='NNGLS 2 layers 50 20 nodes')
lgnd = plt.legend()
for handle in lgnd.legend_handles:
    handle.set_sizes([10.0])
plt.savefig(path + 'l2n50_20.png')

# %%
plt.clf()
plt.scatter(X.detach().numpy(), Y.detach().numpy(), s=1, label='data')
plt.scatter(X.detach().numpy(), funXY(X.detach().numpy()), s=1, label='f(x)')
plt.scatter(X.detach().numpy(), mlp_l1_n5(X).detach().numpy(), s=1, label='NNGLS 1 layer 5 nodes')
plt.scatter(X.detach().numpy(), mlp_l2_n5_2(X).detach().numpy(), s=1, label='NNGLS 2 layers 5 2 nodes')
plt.scatter(X.detach().numpy(), mlp_l1_n50(X).detach().numpy(), s=1, label='NNGLS 1 layer 50 nodes')
plt.scatter(X.detach().numpy(), mlp_l2_n50_20(X).detach().numpy(), s=1, label='NNGLS 2 layers 50 20 nodes')
lgnd = plt.legend()
for handle in lgnd.legend_handles:
    handle.set_sizes([10.0])
plt.show()
